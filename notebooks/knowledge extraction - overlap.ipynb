# %%
import json
import string
from collections import Counter

import pandas as pd
import nltk
from nltk.corpus import stopwords
stopwords = set(stopwords.words('english') + list(string.punctuation))

import tokenization
tokenizer = tokenization.BasicTokenizer(do_lower_case=True)
allowed_pos = ['JJ', 'NN', 'VB', 'RB']

# %%
train_data = pd.read_json('../piqa_data/train.jsonl', orient='records', lines=True)
train_data.head()
# Out:
#                                                 goal  \
# 0      When boiling butter, when it's ready, you can
# 1  To permanently attach metal legs to a chair, y...
# 2                       how do you indent something?
# 3                        how do you shake something?
# 4                                        Clean tires
#
#                                                 sol1  \
# 0                               Pour it onto a plate
# 1  Weld the metal together to get it to stay firm...
# 2          leave a space before starting the writing
# 3      move it up and down and side to side quickly.
# 4  Pour water, cape off caked on dirt. Use  speed...
#
#                                                 sol2
# 0                                 Pour it into a jar
# 1  Nail the metal together to get it to stay firm...
# 2                                 press the spacebar
# 3                              stir it very quickly.
# 4  Pour water, scrape off caked on dirt. Use a st...

# %%
# load wikihow
wikihow = pd.read_csv("../../data/wikihow/wikihowNoText.csv", index_col=0).dropna()
wikihow['content'] = wikihow.apply(lambda r: r['title'] + r['headline'], axis=1)
wikihow.head()
# Out:
#                                         title  \
# index
# 0              How to Be an Organized Artist1
# 1      How to Create a Neopoprealist Art Work
# 2          How to Be a Visual Effects Artist1
# 3               How to Become an Art Investor
# 4              How to Be an Organized Artist2
#
#                                                 headline  \
# index
# 0      \nKeep related supplies in the same area.,\nMa...
# 1      \nCreate a sketch in the NeoPopRealist manner ...
# 2      \nGet a bachelor’s degree.,\nEnroll in a studi...
# 3      \nStart with some experience or interest in ar...
# 4      \nKeep your reference materials, sketches, art...
#
#                                                  content
# index
# 0      How to Be an Organized Artist1\nKeep related s...
# 1      How to Create a Neopoprealist Art Work\nCreate...
# 2      How to Be a Visual Effects Artist1\nGet a bach...
# 3      How to Become an Art Investor\nStart with some...
# 4      How to Be an Organized Artist2\nKeep your refe...

# %%
def sent2tokens(s, tokenizer, stopwords):
    tokens = tokenizer.tokenize(s)
    tokens = [w for w in tokens if w not in stopwords]
    return set(tokens)

# %%
train_data['goal_tokens'] = train_data['goal'].apply(lambda s: sent2tokens(s, tokenizer, stopwords))
train_data['goal_sol1_tokens'] = train_data.apply(
    lambda r: r['goal_tokens'].union(sent2tokens(r['sol1'], tokenizer, stopwords)), axis=1)
train_data['goal_sol2_tokens'] = train_data.apply(
    lambda r: r['goal_tokens'].union(sent2tokens(r['sol2'], tokenizer, stopwords)), axis=1)
train_data.head()
# Out:
#                                                 goal  \
# 0      When boiling butter, when it's ready, you can
# 1  To permanently attach metal legs to a chair, y...
# 2                       how do you indent something?
# 3                        how do you shake something?
# 4                                        Clean tires
#
#                                                 sol1  \
# 0                               Pour it onto a plate
# 1  Weld the metal together to get it to stay firm...
# 2          leave a space before starting the writing
# 3      move it up and down and side to side quickly.
# 4  Pour water, cape off caked on dirt. Use  speed...
#
#                                                 sol2  \
# 0                                 Pour it into a jar
# 1  Nail the metal together to get it to stay firm...
# 2                                 press the spacebar
# 3                              stir it very quickly.
# 4  Pour water, scrape off caked on dirt. Use a st...
#
#                                  goal_tokens  \
# 0                   {ready, boiling, butter}
# 1  {metal, permanently, legs, attach, chair}
# 2                        {indent, something}
# 3                         {shake, something}
# 4                             {clean, tires}
#
#                                     goal_sol1_tokens  \
# 0        {onto, butter, pour, plate, boiling, ready}
# 1  {metal, weld, place, stay, firmly, permanently...
# 2  {starting, indent, leave, space, writing, some...
# 3            {quickly, shake, move, side, something}
# 4  {caked, pour, use, water, speed, wool, crevice...
#
#                                     goal_sol2_tokens
# 0                {jar, butter, pour, boiling, ready}
# 1  {metal, nail, place, stay, firmly, permanently...
# 2               {spacebar, press, indent, something}
# 3                  {shake, quickly, stir, something}
# 4  {caked, pour, use, water, wool, crevices, stee...

# %%
wikihow['content_tokens'] = wikihow['content'].apply(lambda s: sent2tokens(s, tokenizer, stopwords))
wikihow.head()
# Out:
#                                         title  \
# index
# 0              How to Be an Organized Artist1
# 1      How to Create a Neopoprealist Art Work
# 2          How to Be a Visual Effects Artist1
# 3               How to Become an Art Investor
# 4              How to Be an Organized Artist2
#
#                                                 headline  \
# index
# 0      \nKeep related supplies in the same area.,\nMa...
# 1      \nCreate a sketch in the NeoPopRealist manner ...
# 2      \nGet a bachelor’s degree.,\nEnroll in a studi...
# 3      \nStart with some experience or interest in ar...
# 4      \nKeep your reference materials, sketches, art...
#
#                                                  content  \
# index
# 0      How to Be an Organized Artist1\nKeep related s...
# 1      How to Create a Neopoprealist Art Work\nCreate...
# 2      How to Be a Visual Effects Artist1\nGet a bach...
# 3      How to Become an Art Investor\nStart with some...
# 4      How to Be an Organized Artist2\nKeep your refe...
#
#                                           content_tokens
# index
# 0      {ideas, use, inch, place, supplies, permanent,...
# 1      {images, section, coat, primed, background, ve...
# 2      {bachelor, attention, degree, ’, movies, onlin...
# 3      {fine, rather, houses, become, price, interest...
# 4      {necessary, place, supplies, organize, list, e...

# %%
def get_top_overlaps(tokens, threshold=0.2):
    overlaps = wikihow['content_tokens'].apply(lambda x: len(tokens.intersection(x)) / len(x))
    over_threshold = overlaps[overlaps > threshold]
#     print(over_threshold.shape)
    top5 = over_threshold.sort_values(ascending=False)[:5]
    return top5.index.tolist()

# %%
train_data['sol1_knowledge_idx'] = train_data['goal_sol1_tokens'].apply(get_top_overlaps)

# %%
import time
a = time.time()
train_data['sol2_knowledge_idx'] = train_data['goal_sol2_tokens'].apply(get_top_overlaps)
b = time.time()
print(round(b-a, 2), 'sec')
# Out:
# 3008.37 sec

# %%
train_data['sol1_best_knowledge'] = train_data['sol1_knowledge_idx'].apply(
    lambda l: wikihow.loc[l[0]]['content'] if l else "")

# %%
train_data['sol2_best_knowledge'] = train_data['sol2_knowledge_idx'].apply(
    lambda l: wikihow.loc[l[0]]['content'] if l else "")
train_data.head()
# Out:
#                                                 goal  \
# 0      When boiling butter, when it's ready, you can
# 1  To permanently attach metal legs to a chair, y...
# 2                       how do you indent something?
# 3                        how do you shake something?
# 4                                        Clean tires
#
#                                                 sol1  \
# 0                               Pour it onto a plate
# 1  Weld the metal together to get it to stay firm...
# 2          leave a space before starting the writing
# 3      move it up and down and side to side quickly.
# 4  Pour water, cape off caked on dirt. Use  speed...
#
#                                                 sol2  \
# 0                                 Pour it into a jar
# 1  Nail the metal together to get it to stay firm...
# 2                                 press the spacebar
# 3                              stir it very quickly.
# 4  Pour water, scrape off caked on dirt. Use a st...
#
#                                  goal_tokens  \
# 0                   {ready, boiling, butter}
# 1  {metal, permanently, legs, attach, chair}
# 2                        {indent, something}
# 3                         {shake, something}
# 4                             {clean, tires}
#
#                                     goal_sol1_tokens  \
# 0        {onto, butter, pour, plate, boiling, ready}
# 1  {metal, weld, place, stay, firmly, permanently...
# 2  {starting, indent, leave, space, writing, some...
# 3            {quickly, shake, move, side, something}
# 4  {caked, pour, use, water, speed, wool, crevice...
#
#                                     goal_sol2_tokens  \
# 0                {jar, butter, pour, boiling, ready}
# 1  {metal, nail, place, stay, firmly, permanently...
# 2               {spacebar, press, indent, something}
# 3                  {shake, quickly, stir, something}
# 4  {caked, pour, use, water, wool, crevices, stee...
#
#                          sol1_knowledge_idx  \
# 0  [196943, 168565, 158230, 169090, 131919]
# 1    [49690, 176875, 185137, 53962, 205920]
# 2                                  [208399]
# 3                                        []
# 4    [203356, 21043, 33813, 187551, 199629]
#
#                        sol2_knowledge_idx  \
# 0        [131755, 125889, 196943, 188145]
# 1   [49690, 53962, 185137, 176875, 29058]
# 2                                 [59145]
# 3                                      []
# 4  [203356, 21043, 33813, 197807, 199629]
#
#                                  sol1_best_knowledge  \
# 0  How to Unclog a Drain with Salt and Vinegar3\n...
# 1             How to Get Exp. Share5\nTo get an Exp.
# 2  How to Dance2\nGet lined up.,\nPosition the ar...
# 3
# 4  How to Clean Rubber Stamps1\nUse soapy water.,...
#
#                                  sol2_best_knowledge
# 0  How to Make Irish Butter\nPour the Irish cream...
# 1             How to Get Exp. Share5\nTo get an Exp.
# 2               How to Falcon Kick1\nPress B + down.
# 3
# 4  How to Clean Rubber Stamps1\nUse soapy water.,...

# %%
train_with_knowledge = train_data[['goal', 'sol1', 'sol2', 
                                   'sol1_knowledge_idx', 'sol2_knowledge_idx', 
                                   'sol1_best_knowledge', 'sol2_best_knowledge']]
train_with_knowledge.to_json("../piqa_data/train-overlap.jsonl", orient='records', lines=True)

# %% [markdown]
# #### Repeat with Validation Set

# %%
valid = pd.read_json('../piqa_data/valid.jsonl', orient='records', lines=True)
valid.head()
# Out:
#                                                 goal  \
# 0  How do I ready a guinea pig cage for it's new ...
# 1                                            dresser
# 2  To fight Ivan Drago in Rocky for sega master s...
# 3                               Make outdoor pillow.
# 4                                            ice box
#
#                                                 sol1  \
# 0  Provide the guinea pig with a cage full of a f...
# 1                     replace drawer with bobby pin
# 2  Drago isn't in this game because it was releas...
# 3        Blow into tin can and tie with rubber band.
# 4     will turn into a cooler if you add water to it
#
#                                                 sol2
# 0  Provide the guinea pig with a cage full of a f...
# 1                 finish, woodgrain with  bobby pin
# 2  You have to defeat Apollo Creed and Clubber La...
# 3      Blow into trash bag and tie with rubber band.
# 4      will turn into a cooler if you add soda to it

# %%
valid['goal_tokens'] = valid['goal'].apply(lambda s: sent2tokens(s, tokenizer, stopwords))
valid['goal_sol1_tokens'] = valid.apply(
    lambda r: r['goal_tokens'].union(sent2tokens(r['sol1'], tokenizer, stopwords)), axis=1)
valid['goal_sol2_tokens'] = valid.apply(
    lambda r: r['goal_tokens'].union(sent2tokens(r['sol2'], tokenizer, stopwords)), axis=1)
valid.head()
# Out:
#                                                 goal  \
# 0  How do I ready a guinea pig cage for it's new ...
# 1                                            dresser
# 2  To fight Ivan Drago in Rocky for sega master s...
# 3                               Make outdoor pillow.
# 4                                            ice box
#
#                                                 sol1  \
# 0  Provide the guinea pig with a cage full of a f...
# 1                     replace drawer with bobby pin
# 2  Drago isn't in this game because it was releas...
# 3        Blow into tin can and tie with rubber band.
# 4     will turn into a cooler if you add water to it
#
#                                                 sol2  \
# 0  Provide the guinea pig with a cage full of a f...
# 1                 finish, woodgrain with  bobby pin
# 2  You have to defeat Apollo Creed and Clubber La...
# 3      Blow into trash bag and tie with rubber band.
# 4      will turn into a cooler if you add soda to it
#
#                                          goal_tokens  \
# 0         {ready, cage, new, guinea, occupants, pig}
# 1                                          {dresser}
# 2  {ivan, drago, fight, rocky, master, system, sega}
# 3                            {pillow, outdoor, make}
# 4                                         {box, ice}
#
#                                     goal_sol1_tokens  \
# 0  {water, bedding, dish, ready, new, also, food,...
# 1             {drawer, bobby, replace, pin, dresser}
# 2  {released, ivan, drago, fight, iv, rocky, mast...
# 3  {pillow, tin, make, blow, outdoor, band, tie, ...
# 4               {cooler, water, box, ice, add, turn}
#
#                                     goal_sol2_tokens
# 0  {water, bedding, dish, ready, new, jeans, mate...
# 1           {bobby, finish, pin, dresser, woodgrain}
# 2  {ivan, lang, drago, fight, defeat, rocky, cree...
# 3  {pillow, bag, make, blow, outdoor, trash, band...
# 4                {soda, cooler, box, ice, add, turn}

# %%
import time
a = time.time()
valid['sol1_knowledge_idx'] = valid['goal_sol1_tokens'].apply(get_top_overlaps)
valid['sol2_knowledge_idx'] = valid['goal_sol2_tokens'].apply(get_top_overlaps)
b = time.time()
print(round(b-a, 2), 'sec')
# Out:
# 635.45 sec

# %%
valid.head()
# Out:
#                                                 goal  \
# 0  How do I ready a guinea pig cage for it's new ...
# 1                                            dresser
# 2  To fight Ivan Drago in Rocky for sega master s...
# 3                               Make outdoor pillow.
# 4                                            ice box
#
#                                                 sol1  \
# 0  Provide the guinea pig with a cage full of a f...
# 1                     replace drawer with bobby pin
# 2  Drago isn't in this game because it was releas...
# 3        Blow into tin can and tie with rubber band.
# 4     will turn into a cooler if you add water to it
#
#                                                 sol2  \
# 0  Provide the guinea pig with a cage full of a f...
# 1                 finish, woodgrain with  bobby pin
# 2  You have to defeat Apollo Creed and Clubber La...
# 3      Blow into trash bag and tie with rubber band.
# 4      will turn into a cooler if you add soda to it
#
#                                          goal_tokens  \
# 0         {ready, cage, new, guinea, occupants, pig}
# 1                                          {dresser}
# 2  {ivan, drago, fight, rocky, master, system, sega}
# 3                            {pillow, outdoor, make}
# 4                                         {box, ice}
#
#                                     goal_sol1_tokens  \
# 0  {water, bedding, dish, ready, new, also, food,...
# 1             {drawer, bobby, replace, pin, dresser}
# 2  {released, ivan, drago, fight, iv, rocky, mast...
# 3  {pillow, tin, make, blow, outdoor, band, tie, ...
# 4               {cooler, water, box, ice, add, turn}
#
#                                     goal_sol2_tokens  \
# 0  {water, bedding, dish, ready, new, jeans, mate...
# 1           {bobby, finish, pin, dresser, woodgrain}
# 2  {ivan, lang, drago, fight, defeat, rocky, cree...
# 3  {pillow, bag, make, blow, outdoor, trash, band...
# 4                {soda, cooler, box, ice, add, turn}
#
#                          sol1_knowledge_idx  \
# 0      [12402, 169134, 65609, 185220, 1348]
# 1                                        []
# 2                                  [165894]
# 3  [204891, 201779, 183496, 202389, 206281]
# 4  [185220, 157466, 118688, 159645, 134496]
#
#                          sol2_knowledge_idx
# 0        [12402, 65609, 1348, 185220, 1329]
# 1                                        []
# 2             [165894, 55026, 55025, 55024]
# 3     [91673, 79263, 204891, 91672, 201779]
# 4  [118688, 157476, 188953, 104011, 104012]

# %%
valid['sol1_best_knowledge'] = valid['sol1_knowledge_idx'].apply(
    lambda l: wikihow.loc[l[0]]['content'] if l else "")
valid['sol2_best_knowledge'] = valid['sol2_knowledge_idx'].apply(
    lambda l: wikihow.loc[l[0]]['content'] if l else "")

# %%
valid_with_knowledge = valid[['goal', 'sol1', 'sol2', 
                                   'sol1_knowledge_idx', 'sol2_knowledge_idx', 
                                   'sol1_best_knowledge', 'sol2_best_knowledge']]
valid_with_knowledge.to_json("../piqa_data/valid-overlap.jsonl", orient='records', lines=True)

# %%
valid_with_knowledge.head()
# Out:
#                                                 goal  \
# 0  How do I ready a guinea pig cage for it's new ...
# 1                                            dresser
# 2  To fight Ivan Drago in Rocky for sega master s...
# 3                               Make outdoor pillow.
# 4                                            ice box
#
#                                                 sol1  \
# 0  Provide the guinea pig with a cage full of a f...
# 1                     replace drawer with bobby pin
# 2  Drago isn't in this game because it was releas...
# 3        Blow into tin can and tie with rubber band.
# 4     will turn into a cooler if you add water to it
#
#                                                 sol2  \
# 0  Provide the guinea pig with a cage full of a f...
# 1                 finish, woodgrain with  bobby pin
# 2  You have to defeat Apollo Creed and Clubber La...
# 3      Blow into trash bag and tie with rubber band.
# 4      will turn into a cooler if you add soda to it
#
#                          sol1_knowledge_idx  \
# 0      [12402, 169134, 65609, 185220, 1348]
# 1                                        []
# 2                                  [165894]
# 3  [204891, 201779, 183496, 202389, 206281]
# 4  [185220, 157466, 118688, 159645, 134496]
#
#                          sol2_knowledge_idx  \
# 0        [12402, 65609, 1348, 185220, 1329]
# 1                                        []
# 2             [165894, 55026, 55025, 55024]
# 3     [91673, 79263, 204891, 91672, 201779]
# 4  [118688, 157476, 188953, 104011, 104012]
#
#                                  sol1_best_knowledge  \
# 0  How to Care for Snails2\nGive the snail calciu...
# 1
# 2     How to Rename a Drive2\nRename a system drive.
# 3  How to Make a Pillow Stand for iPad1\nDownload...
# 4  How to Install a New Dishwasher1\nTurn off the...
#
#                                  sol2_best_knowledge
# 0  How to Care for Snails2\nGive the snail calciu...
# 1
# 2     How to Rename a Drive2\nRename a system drive.
# 3                  How to Be  Green2\nPick up trash.
# 4  How to Stretch Your Back While Sitting2\nDo a ...

# %%
wikihow.loc[131755]
# Out:
# title                                      How to Make Irish Butter
# headline          \nPour the Irish cream into a large clean jar....
# content           How to Make Irish Butter\nPour the Irish cream...
# content_tokens    {jar, pour, make, refrigerator, store, large, ...
# Name: 131755, dtype: object

# %% [markdown]
# ### archive

# %%
overlaps = wikihow['content_tokens'].apply(
    lambda x: len(question_option_tokens.intersection(x)) / len(question_option_tokens))
overlaps[overlaps > 0.75].sort_values()
# Out:
# index
# 87311     0.833333
# 125924    0.833333
# 126389    0.833333
# 129723    0.833333
# 130992    0.833333
# 132308    0.833333
# Name: content_tokens, dtype: float64

# %%
overlaps2 = wikihow['content_tokens'].apply(
    lambda x: len(question_option_tokens.intersection(x)) / len(x))
overlaps2[overlaps2 > 0.2].sort_values(ascending=False)
# Out:
# index
# 196943    0.222222
# 168565    0.222222
# 158230    0.222222
# 169090    0.214286
# 131919    0.214286
# Name: content_tokens, dtype: float64
